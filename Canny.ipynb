# %% [markdown]
# <a href="https://colab.research.google.com/github/Aldoptma0704/Image-Feature-Extraction/blob/main/Canny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/trainingdatapro/male-selfie-image-dataset

# %%
#Import Library yang diperlukan
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpig

# %%
img = cv2.imread('Output/1.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.show()

# %%
edges = cv2.Canny(image, 100, 200)

# %%
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.title("Canny Edge Detection")
plt.show()
