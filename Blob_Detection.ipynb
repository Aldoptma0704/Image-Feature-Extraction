# %% [markdown]
# <a href="https://colab.research.google.com/github/Aldoptma0704/Image-Feature-Extraction/blob/main/Blob_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.io import imread, imshow
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

im = rgb2gray(imread('Output/4.jpg'))
imshow(im);

# %%
im_bw = (im < 0.5) * 1
im_mask = im < 0.5
imshow(im_bw, cmap='gray');
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# #Laplacian of Gaussian (LoG)

# %%
from skimage.feature import blob_log
import numpy as np # Added import statement

blobs = blob_log(im_mask, max_sigma=30, num_sigma=10, threshold=0.1)

fig, ax = plt.subplots()
ax.imshow(im_bw, cmap='gray')
for blob in blobs:
    y, x, area = blob
    ax.add_patch(plt.Circle((x, y), area*np.sqrt(2), color='y', fill=False))
plt.show()

# %% [markdown]
# #Difference of Gaussian (DoG)

# %%
from skimage.feature import blob_dog

blobs = blob_dog(im_mask, max_sigma=30, threshold=.1)

fig, ax = plt.subplots()
ax.imshow(im_bw, cmap='gray')
for blob in blobs:
    y, x, area = blob
    ax.add_patch(plt.Circle((x, y), area*np.sqrt(2), color='g', fill=False))
plt.show()

# %% [markdown]
# #Determinant of Hessian (DoH)

# %%
from skimage.feature import blob_doh

blobs = blob_doh(im_mask, max_sigma=30, threshold=.01)

fig, ax = plt.subplots()
ax.imshow(im_bw, cmap='gray')
for blob in blobs:
    y, x, area = blob
    ax.add_patch(plt.Circle((x, y), area*np.sqrt(2), color='r', fill=False))
plt.show()
